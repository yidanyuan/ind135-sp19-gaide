# %%
#train an CNN model for the accent detector
#for low tech demo: onlhy destringuish us accents with others 

#import models to be used
import numpy as np
import pandas as pd
import librosa
import multiprocessing
import sys
import os

from collections import Counter

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from keras import utils
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Flatten
from keras.layers.convolutional import MaxPooling2D, Conv2D
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, TensorBoard
# Out:
# Using TensorFlow backend.

# %%
DEBUG = True
SILENCE_THRESHOLD = .01
RATE = 24000
N_MFCC = 13
COL_SIZE = 30
EPOCHS = 10 #35#250

# %%
#get audio data and information from speech accent archive using Webscraping
import os # To interact with operating system and format file name
import shutil # To copy file object from python to disk
import requests
import bs4 as bs 
from collections import Counter
import re
import urllib.request
import sys
from pydub import AudioSegment
#source = requests.get("http://accent.gmu.edu/browse_language.php")
#soup = bs.BeautifulSoup(source.content, features='html.parser') 
#print(soup.prettify())

# %%
"""specify desired languages; 
for now (check point #1): only english and mandarin are used;
eventually/ideally, all languages will be used"""
languages = ["mandarin","english"]
URL = 'http://accent.gmu.edu/'
mp3_url = 'http://chnm.gmu.edu/accent/soundtracks/{}.mp3'

# %%
#get data and bio information from the url
def create_df(languages = languages, url = URL):
    import bs4 as bs 
    search_url = [url+'browse_language.php?function=find&language={}'.format(l) for l in languages]
    htmls = []
    for url in search_url:
        #print('downloading from {}'.format(url))
        htmls.append(requests.get(url).text)
    #print(htmls)
    
    bss = [bs.BeautifulSoup(html,'html.parser') for html in htmls]
    #print(bss)
    people = []
    counter = 0
    for b in bss:
        
        for p in b.find_all('p'):
            counter += 1
            if p.a:
                text = p.text.replace(' ','').split(',')
                address = 'http://accent.gmu.edu/'+p.a['href']
                speakerid = address.split('speakerid=')[1]
                #print(speakerid)
                s = bs.BeautifulSoup(requests.get(address).text,'html.parser')
                each_bio = [li.text for li in s.find('ul','bio').find_all('li')]
                native_language = each_bio[1].split(': ')[1]
                eng_residence = each_bio[6].split(': ')[1]
                if native_language.find("english") != -1 and eng_residence.find('usa') != -1:
                    if_us_native = 1
                else:
                    if_us_native = 0
                x = [speakerid,address, text[0], text[1],native_language, if_us_native]
                #print(counter)
                #print(x)
                
                people.append(x)
                                
    df = pd.DataFrame(people, columns=['speakerid','href','language_num','gender',\
                                       'native_language','if_us_native'])
    
    return df

# %%
df = create_df()
df
# Out:
#     speakerid                                               href language_num  \
# 0         256  http://accent.gmu.edu/browse_language.php?func...    mandarin1
# 1         257  http://accent.gmu.edu/browse_language.php?func...    mandarin2
# 2         258  http://accent.gmu.edu/browse_language.php?func...    mandarin3
# 3         259  http://accent.gmu.edu/browse_language.php?func...    mandarin4
# 4         260  http://accent.gmu.edu/browse_language.php?func...    mandarin5
# 5         261  http://accent.gmu.edu/browse_language.php?func...    mandarin6
# 6         262  http://accent.gmu.edu/browse_language.php?func...    mandarin7
# 7         430  http://accent.gmu.edu/browse_language.php?func...    mandarin8
# 8         451  http://accent.gmu.edu/browse_language.php?func...    mandarin9
# 9         491  http://accent.gmu.edu/browse_language.php?func...   mandarin10
# 10        607  http://accent.gmu.edu/browse_language.php?func...   mandarin11
# 11        623  http://accent.gmu.edu/browse_language.php?func...   mandarin12
# 12        685  http://accent.gmu.edu/browse_language.php?func...   mandarin13
# 13        719  http://accent.gmu.edu/browse_language.php?func...   mandarin14
# 14        746  http://accent.gmu.edu/browse_language.php?func...   mandarin15
# 15        750  http://accent.gmu.edu/browse_language.php?func...   mandarin16
# 16        796  http://accent.gmu.edu/browse_language.php?func...   mandarin17
# 17        872  http://accent.gmu.edu/browse_language.php?func...   mandarin18
# 18        916  http://accent.gmu.edu/browse_language.php?func...   mandarin19
# 19        931  http://accent.gmu.edu/browse_language.php?func...   mandarin20
# 20        984  http://accent.gmu.edu/browse_language.php?func...   mandarin21
# 21       1019  http://accent.gmu.edu/browse_language.php?func...   mandarin22
# 22       1044  http://accent.gmu.edu/browse_language.php?func...   mandarin23
# 23       1089  http://accent.gmu.edu/browse_language.php?func...   mandarin24
# 24       1125  http://accent.gmu.edu/browse_language.php?func...   mandarin25
# 25       1141  http://accent.gmu.edu/browse_language.php?func...   mandarin26
# 26       1154  http://accent.gmu.edu/browse_language.php?func...   mandarin27
# 27       1447  http://accent.gmu.edu/browse_language.php?func...   mandarin28
# 28       1490  http://accent.gmu.edu/browse_language.php?func...   mandarin29
# 29       1491  http://accent.gmu.edu/browse_language.php?func...   mandarin30
# ..        ...                                                ...          ...
# 728      2381  http://accent.gmu.edu/browse_language.php?func...   english597
# 729      2382  http://accent.gmu.edu/browse_language.php?func...   english598
# 730      2383  http://accent.gmu.edu/browse_language.php?func...   english599
# 731      2385  http://accent.gmu.edu/browse_language.php?func...   english600
# 732      2404  http://accent.gmu.edu/browse_language.php?func...   english601
# 733      2405  http://accent.gmu.edu/browse_language.php?func...   english602
# 734      2428  http://accent.gmu.edu/browse_language.php?func...   english603
# 735      2438  http://accent.gmu.edu/browse_language.php?func...   english604
# 736      2439  http://accent.gmu.edu/browse_language.php?func...   english605
# 737      2440  http://accent.gmu.edu/browse_language.php?func...   english606
# 738      2441  http://accent.gmu.edu/browse_language.php?func...   english607
# 739      2442  http://accent.gmu.edu/browse_language.php?func...   english608
# 740      2443  http://accent.gmu.edu/browse_language.php?func...   english609
# 741      2444  http://accent.gmu.edu/browse_language.php?func...   english610
# 742      2445  http://accent.gmu.edu/browse_language.php?func...   english611
# 743      2533  http://accent.gmu.edu/browse_language.php?func...   english612
# 744      2570  http://accent.gmu.edu/browse_language.php?func...   english613
# 745      2606  http://accent.gmu.edu/browse_language.php?func...   english614
# 746      2613  http://accent.gmu.edu/browse_language.php?func...   english615
# 747      2619  http://accent.gmu.edu/browse_language.php?func...   english616
# 748      2630  http://accent.gmu.edu/browse_language.php?func...   english617
# 749      2674  http://accent.gmu.edu/browse_language.php?func...   english618
# 750      2724  http://accent.gmu.edu/browse_language.php?func...   english619
# 751      2735  http://accent.gmu.edu/browse_language.php?func...   english620
# 752      2793  http://accent.gmu.edu/browse_language.php?func...   english621
# 753      2799  http://accent.gmu.edu/browse_language.php?func...   english622
# 754      2803  http://accent.gmu.edu/browse_language.php?func...   english623
# 755      2804  http://accent.gmu.edu/browse_language.php?func...   english624
# 756      2805  http://accent.gmu.edu/browse_language.php?func...   english625
# 757      2806  http://accent.gmu.edu/browse_language.php?func...   english626
#
#      gender native_language  if_us_native
# 0    female  mandarin (cmn)             0
# 1    female  mandarin (cmn)             0
# 2      male  mandarin (cmn)             0
# 3    female  mandarin (cmn)             0
# 4    female  mandarin (cmn)             0
# 5    female  mandarin (cmn)             0
# 6      male  mandarin (cmn)             0
# 7      male  mandarin (cmn)             0
# 8      male  mandarin (cmn)             0
# 9      male  mandarin (cmn)             0
# 10   female  mandarin (cmn)             0
# 11     male  mandarin (cmn)             0
# 12     male  mandarin (cmn)             0
# 13     male  mandarin (cmn)             0
# 14   female  mandarin (cmn)             0
# 15     male  mandarin (cmn)             0
# 16     male  mandarin (cmn)             0
# 17   female  mandarin (cmn)             0
# 18     male  mandarin (cmn)             0
# 19   female  mandarin (cmn)             0
# 20   female  mandarin (cmn)             0
# 21   female  mandarin (cmn)             0
# 22   female  mandarin (cmn)             0
# 23   female  mandarin (cmn)             0
# 24   female  mandarin (cmn)             0
# 25   female  mandarin (cmn)             0
# 26     male  mandarin (cmn)             0
# 27     male  mandarin (cmn)             0
# 28     male  mandarin (cmn)             0
# 29     male  mandarin (cmn)             0
# ..      ...             ...           ...
# 728    male   english (eng)             1
# 729    male   english (eng)             1
# 730  female   english (eng)             1
# 731  female   english (eng)             1
# 732    male   english (eng)             1
# 733  female   english (eng)             1
# 734    male   english (eng)             1
# 735  female   english (eng)             0
# 736    male   english (eng)             0
# 737  female   english (eng)             0
# 738  female   english (eng)             0
# 739    male   english (eng)             0
# 740  female   english (eng)             0
# 741  female   english (eng)             0
# 742    male   english (eng)             0
# 743    male   english (eng)             0
# 744    male   english (eng)             0
# 745  female   english (eng)             1
# 746    male   english (eng)             0
# 747    male   english (eng)             1
# 748  female   english (eng)             0
# 749    male   english (eng)             1
# 750    male   english (eng)             1
# 751    male   english (eng)             1
# 752  female   english (eng)             1
# 753  female   english (eng)             1
# 754    male   english (eng)             1
# 755    male   english (eng)             1
# 756    male   english (eng)             1
# 757  female   english (eng)             1
#
# [758 rows x 6 columns]

# %%
#some helper code scratch
#df.groupby('if_us_native').count()
"""source = bs.BeautifulSoup(requests.get(df['href'][len(df['href'])-1]).text,'html.parser')
each_bio = [li.text for li in source.find('ul','bio').find_all('li')]
each_bio"""
path = os.getcwd()  
print ("The current working directory is %s" % path)
# Out:
# The current working directory is /Users/Ming/Desktop/ind135-sp19-gaide

# %%
df.groupby('if_us_native').count()
# Out:
#               speakerid  href  language_num  gender  native_language
# if_us_native
# 0                   301   301           301     301              301
# 1                   457   457           457     457              457

# %%
def get_audio(df,destination_folder,url = mp3_url):
    
    if not os.path.exists(destination_folder):
        print('creating audio destination folder'.format(destination_folder))
        os.makedirs(os.getcwd() + "/" + destination_folder)
    else:
        print('audio destination folder already exists.')
            
    counter = 0
    for lang_num in df['language_num']:
        if not os.path.exists(destination_folder +'{}.wav'.format(lang_num)):
            print('downloading {}'.format(lang_num))
            (filename, headers) = urllib.request.urlretrieve(url.format(lang_num))
            sound = AudioSegment.from_mp3(filename)
            sound.export(os.getcwd() +"/"+ destination_folder + "{}.wav".format(lang_num),\
                         format="wav")
            counter += 1

    return counter

# %%
# get_audio(df, 'wav')

# %%
from scipy.io import wavfile
from matplotlib import pyplot as plt
import numpy as np
import os
import librosa
import glob

# %%
#get filenames

filenames = []

for file in df.loc[:, "language_num"]:
    filenames.append("wav/wav" + file + ".wav")
        
label = df.loc[:, "if_us_native"]

d = {'filename': filenames, 'label': label}
train = pd.DataFrame(data=d)

# %%
def parser(file_name):
    try:
      # here kaiser_fast is a technique used for faster extraction
      X, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
      # we extract mfcc feature from data
      mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0)

    except Exception as e:
        print("Error encountered while parsing file: ", file)
        return None, None
    return (mfccs)

feature = []
for i in range(len(filenames)):
    feature.append(parser(filenames[i]))
     

temp = pd.DataFrame({'feature': feature, 'label': label})

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.python.keras import utils

X = np.array(temp.feature.tolist())
y = np.array(temp.label.tolist())

lb = LabelEncoder()

y = utils.to_categorical(lb.fit_transform(y))

# %%
valX = X[len(X) - 100:]
valY = y[len(y) - 100:]


X = X[0:len(X) - 100]
y = y[0:len(y) - 100]
# Out:
# 100

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, MaxPooling2D
from keras.optimizers import Adam
from keras.utils import np_utils
from sklearn import metrics 

num_labels = y.shape[1]
filter_size = 2

# build model
model = Sequential()

model.add(Dense(256, input_shape=(40,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(num_labels))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
model.fit(X, y, batch_size=32, epochs=5, validation_data=(valX, valY))
# Out:
# Train on 658 samples, validate on 100 samples
# Epoch 1/5
# 658/658 [==============================] - 1s 1ms/step - loss: 6.0734 - acc: 0.5866 - val_loss: 3.5460 - val_acc: 0.7800
# Epoch 2/5
# 658/658 [==============================] - 0s 110us/step - loss: 6.7258 - acc: 0.5775 - val_loss: 3.5460 - val_acc: 0.7800
# Epoch 3/5
# 658/658 [==============================] - 0s 102us/step - loss: 6.8214 - acc: 0.5729 - val_loss: 3.5460 - val_acc: 0.7800
# Epoch 4/5
# 658/658 [==============================] - 0s 105us/step - loss: 6.8343 - acc: 0.5760 - val_loss: 3.5460 - val_acc: 0.7800
# Epoch 5/5
# 658/658 [==============================] - 0s 110us/step - loss: 6.7626 - acc: 0.5790 - val_loss: 3.5460 - val_acc: 0.7800
